# %%
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt

DB_PATH = "data.sqlite"
conn = sqlite3.connect(DB_PATH)

prices = pd.read_sql_query(
    "SELECT symbol, date, close FROM prices WHERE symbol IN ('SPY','QQQ') ORDER BY date",
    conn
)

metrics = pd.read_sql_query(
    "SELECT * FROM derived_metrics WHERE symbol IN ('SPY','QQQ') ORDER BY date",
    conn
)

stress = pd.read_sql_query(
    "SELECT * FROM market_stress ORDER BY date",
    conn
)

conn.close()

prices["date"] = pd.to_datetime(prices["date"])
metrics["date"] = pd.to_datetime(metrics["date"])
stress["date"] = pd.to_datetime(stress["date"])

prices.tail()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\moodys-risk-monitor\.venv\Lib\site-packages\pandas\io\sql.py:2702, in SQLiteDatabase.execute(self, sql, params)
#    2701 try:
# -> 2702     cur.execute(sql, *args)
#    2703     return cur
#
# OperationalError: no such table: prices
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[1], line 8
#       5 DB_PATH = "../data.sqlite"
#       6 conn = sqlite3.connect(DB_PATH)
# ----> 8 prices = pd.read_sql_query(
#       9     "SELECT symbol, date, close FROM prices WHERE symbol IN ('SPY','QQQ') ORDER BY date",
#      10     conn
#      11 )
#      13 metrics = pd.read_sql_query(
#      14     "SELECT * FROM derived_metrics WHERE symbol IN ('SPY','QQQ') ORDER BY date",
#      15     conn
#      16 )
#      18 stress = pd.read_sql_query(
#      19     "SELECT * FROM market_stress ORDER BY date",
#      20     conn
#      21 )
#
# File ~\moodys-risk-monitor\.venv\Lib\site-packages\pandas\io\sql.py:497, in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype, dtype_backend)
#     494 assert dtype_backend is not lib.no_default
#     496 with pandasSQL_builder(con) as pandas_sql:
# --> 497     return pandas_sql.read_query(
#     498         sql,
#     499         index_col=index_col,
#     500         params=params,
#     501         coerce_float=coerce_float,
#     502         parse_dates=parse_dates,
#     503         chunksize=chunksize,
#     504         dtype=dtype,
#     505         dtype_backend=dtype_backend,
#     506     )
#
# File ~\moodys-risk-monitor\.venv\Lib\site-packages\pandas\io\sql.py:2766, in SQLiteDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2755 def read_query(
#    2756     self,
#    2757     sql,
#    (...)   2764     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2765 ) -> DataFrame | Iterator[DataFrame]:
# -> 2766     cursor = self.execute(sql, params)
#    2767     columns = [col_desc[0] for col_desc in cursor.description]
#    2769     if chunksize is not None:
#
# File ~\moodys-risk-monitor\.venv\Lib\site-packages\pandas\io\sql.py:2714, in SQLiteDatabase.execute(self, sql, params)
#    2711     raise ex from inner_exc
#    2713 ex = DatabaseError(f"Execution failed on sql '{sql}': {exc}")
# -> 2714 raise ex from exc
#
# DatabaseError: Execution failed on sql 'SELECT symbol, date, close FROM prices WHERE symbol IN ('SPY','QQQ') ORDER BY date': no such table: prices

# %%
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt

DB_PATH = "../data.sqlite"
conn = sqlite3.connect(DB_PATH)

prices = pd.read_sql_query(
    "SELECT symbol, date, close FROM prices WHERE symbol IN ('SPY','QQQ') ORDER BY date",
    conn
)

metrics = pd.read_sql_query(
    "SELECT * FROM derived_metrics WHERE symbol IN ('SPY','QQQ') ORDER BY date",
    conn
)

stress = pd.read_sql_query(
    "SELECT * FROM market_stress ORDER BY date",
    conn
)

conn.close()

prices["date"] = pd.to_datetime(prices["date"])
metrics["date"] = pd.to_datetime(metrics["date"])
stress["date"] = pd.to_datetime(stress["date"])

prices.tail()

# %%
1+1
# Out:
# 2

# %%
import os
print("CWD:", os.getcwd())
print("Exists ../data.sqlite ?", os.path.exists("../data.sqlite"))
print("Exists data.sqlite ?", os.path.exists("data.sqlite"))
print("Exists C:/Users/Begum/moodys-risk-monitor/data.sqlite ?", os.path.exists(r"C:\Users\Begum\moodys-risk-monitor\data.sqlite"))
# Out:
# CWD: C:\Users\Begum\moodys-risk-monitor
# Exists ../data.sqlite ? True
# Exists data.sqlite ? True
# Exists C:/Users/Begum/moodys-risk-monitor/data.sqlite ? True

# %%
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt

DB_PATH = "data.sqlite"
conn = sqlite3.connect(DB_PATH)

prices = pd.read_sql_query(
    "SELECT symbol, date, close FROM prices WHERE symbol IN ('SPY','QQQ') ORDER BY date",
    conn
)

metrics = pd.read_sql_query(
    "SELECT * FROM derived_metrics WHERE symbol IN ('SPY','QQQ') ORDER BY date",
    conn
)

stress = pd.read_sql_query(
    "SELECT * FROM market_stress ORDER BY date",
    conn
)

conn.close()

prices["date"] = pd.to_datetime(prices["date"])
metrics["date"] = pd.to_datetime(metrics["date"])
stress["date"] = pd.to_datetime(stress["date"])

prices.tail()
# Out:
#      symbol       date   close
# 6874    SPY 2026-02-18  686.29
# 6875    QQQ 2026-02-19  603.47
# 6876    SPY 2026-02-19  684.48
# 6877    QQQ 2026-02-20  608.81
# 6878    SPY 2026-02-20  689.43

# %%
import matplotlib.pyplot as plt

prices_sorted = prices.sort_values(["symbol", "date"])

plt.figure()
for sym in ["SPY", "QQQ"]:
    df = prices_sorted[prices_sorted["symbol"] == sym]
    plt.plot(df["date"], df["close"], label=sym)
plt.title("Prices: SPY vs QQQ")
plt.xlabel("Date")
plt.ylabel("Close")
plt.legend()
plt.show()

# %%
plt.figure()
for sym in ["SPY", "QQQ"]:
    df = metrics[metrics["symbol"] == sym].dropna(subset=["vol_30d_ann"])
    plt.plot(df["date"], df["vol_30d_ann"], label=sym)
plt.title("30D Annualized Volatility")
plt.xlabel("Date")
plt.ylabel("Vol (ann.)")
plt.legend()
plt.show()

# %%
plt.figure()
for sym in ["SPY", "QQQ"]:
    df = metrics[metrics["symbol"] == sym].dropna(subset=["drawdown"])
    plt.plot(df["date"], df["drawdown"], label=sym)
plt.title("Drawdown from Peak")
plt.xlabel("Date")
plt.ylabel("Drawdown")
plt.legend()
plt.show()

# %%
plt.figure()
plt.plot(stress["date"], stress["slope_10y_2y"])
plt.axhline(0)
plt.title("Yield Curve Slope (10Y - 2Y)")
plt.xlabel("Date")
plt.ylabel("Slope")
plt.show()

stress.tail(10)
# Out:
#             date  slope_10y_2y  inversion_flag
# 12415 2026-02-05          0.74               0
# 12416 2026-02-06          0.72               0
# 12417 2026-02-09          0.74               0
# 12418 2026-02-10          0.71               0
# 12419 2026-02-11          0.66               0
# 12420 2026-02-12          0.62               0
# 12421 2026-02-13          0.64               0
# 12422 2026-02-17          0.62               0
# 12423 2026-02-18          0.62               0
# 12424 2026-02-19          0.61               0

# %%
watchlist = pd.read_csv("outputs/daily_watchlist.csv")
watchlist
# Out:
#   symbol        date  return_1d  vol_30d_ann  drawdown    var_95  flag_vol  \
# 0    QQQ  2026-02-20   0.008849     0.164969 -0.042405 -0.020976      True
# 1    SPY  2026-02-20   0.007232     0.121983 -0.008713 -0.012765     False
#
#    flag_dd  flag_var  flags_count
# 0     True     False            2
# 1    False     False            0

# %%
latest_date = watchlist["date"].max()
today = watchlist[watchlist["date"] == latest_date].copy()

print("DATE:", latest_date)
display(today.sort_values("flags_count", ascending=False))

top = today.sort_values("flags_count", ascending=False).iloc[0]
print("\nKey takeaway:")
print(f"- Highest flags: {top['symbol']} (flags_count={int(top['flags_count'])})")
# Out:
# DATE: 2026-02-20
#   symbol        date  return_1d  vol_30d_ann  drawdown    var_95  flag_vol  \
# 0    QQQ  2026-02-20   0.008849     0.164969 -0.042405 -0.020976      True
# 1    SPY  2026-02-20   0.007232     0.121983 -0.008713 -0.012765     False
#
#    flag_dd  flag_var  flags_count
# 0     True     False            2
# 1    False     False            0
# Key takeaway:
# - Highest flags: QQQ (flags_count=2)
